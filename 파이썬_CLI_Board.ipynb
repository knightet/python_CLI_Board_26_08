# %% [markdown]
# <a href="https://colab.research.google.com/github/knightet/python_CLI_Board_26_08/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_CLI_Board.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import datetime
# #만든 내용 클래스 화
# user = input("사용자 입력")
# i = 1
# class auth:
#   def __init__(self)
#     self.login_id = 1
#     self.profiles = []

#   def register(self)


#   def login(self)



# def makeTestData():
#   # 시작하자마자 넣어둘 테스트용 글 3개를 만들어서 리스트로 리턴한다
#   # 1번은 이전 날짜 -> 목록 날짜 표기 테스트용
#   return [
#       {"id" : 1, "regDate" : "2025-12-12 12:12:12", "updateDate" : "2025-12-12 12:12:12", "title" : "제목1","body":"내용1"},
#       {"id" : 2, "regDate" : now(), "updateDate" : now(), "title" : "제목2","body":"내용2"},
#       {"id" : 3, "regDate" : now(), "updateDate" : now(), "title" : "제목3","body":"내용3"}
#           ]

# class cli:
#   def __init__(self): # 게시글 실행
#     self.article_id = 1
#     self.articles = []

#   def article_write(self): # 게시글 생성
#     kst_time = datetime.datetime.now(datetime.UTC) + datetime.timedelta(hours=9)
#     time = kst_time.strftime('%Y-%m-%d %H:%M:%S')# 시간 설정
#     title = input("제목 : ")
#     main = input("내용 : ")
#     article = {
#             "id": self.article_id,
#             "title": title,
#             "main": main,
#             "time": time,
#             "updatetime" : time
#         }
#     self.articles.append(article)

#     print("{}번 글이 생성되었습니다.".format(self.article_id))
#     self.article_id +=1

#   def exit(self): # 게시판 나가는것
#     print("== CLI 게시판 종료 ==")

#   def help(self):# 게시판 명령어 확인
#     print("명령어 확인")
#     print("article write == 게시판 생성")
#     print("exit == 게시판 종료")
#     print("article list == 게시판 확인")

#   def article_list(self):
#     print("="*30)
#     print("{}  /   {}   /   {}  ".format("번호","제목","내용"))
#     for article in reversed(self.articles):
#        print("{}    /    {}    /    {}   ".format(article["id"], article["title"], article["main"]))
#     print("="*30)
#   def article_delete(self):
#     if not self.articles:
#       print("삭제할 게시글이 없습니다.")
#       return
#     else:
#       num = s.split(" ")
#       target_id = int(num[2])
#       # 입력받은 번호(id)와 일치하는 게시글 찾기
#       target_article = None
#       for article in self.articles:
#         if article["id"] == target_id:
#             target_article = article
#             break
#     if target_article:
#             self.articles.remove(target_article)
#             print("{}번 게시글이 삭제되었습니다.".format(target_id))
#     else:
#             print("{}번 게시글이 존재하지 않습니다.".format(target_id))

#   def article_edit(self):# 수정 하는 부분
#     num = s.split(" ")
#     target_id = int(num[2])
#     target_article = None
#     if not self.articles:
#         print("수정할 게시글이 없습니다.")
#         return
#     for article in self.articles:
#       if article["id"] == target_id:
#           target_article = article
#           break
#     if target_article:
#       print("{}번 게시글 수정내용을 입력해주세요.".format(target_id))
#     else:
#       print("{}번 게시글이 존재하지 않습니다.".format(target_id))
#       return
#     edit_title = input("제목 : ")
#     edit_main = input("내용 : ")
#     kst_time = datetime.datetime.now(datetime.UTC) + datetime.timedelta(hours=9)
#     time = kst_time.strftime('%Y-%m-%d %H:%M:%S')
#     target_article["title"] = edit_title
#     target_article["main"] = edit_main
#     target_article["updatetime"] = time

#   def article_detail(self): # 자세히 확인하는 부분
#     num = s.split(" ")
#     target_id = int(num[2])
#     target_article = None
#     for article in self.articles:
#       if article["id"] == target_id:
#           target_article = article
#           break
#     if target_article:
#       print("{}번 게시글 입니다.".format(target_id))
#       print("작성 시간 : {}".format(target_article["time"]))
#       print("수정 시간 : {}".format(target_article["updatetime"]))
#       print("제목 : {}".format(target_article["title"]))
#       print("내용 : {}".format(target_article["main"]))
#     else:
#       print("{}번 게시글이 존재하지 않습니다.".format(target_id))
#       return

# board = cli()

# print("환영합니다.{}".format(user))
# print("== CLI 게시판 실행 ==")
# while(1):
#   sys.exit()

# while(1):
#   s = input("명령어 : ")
#   if (s == "article write"):
#     board.article_write()
#   elif (s  == "exit"):
#     board.exit()
#     break
#   elif (s  == "help"):
#     board.help()
#   elif (s.startswith("article list")):
#     board.article_list()
#   elif (s.startswith("article delete")):
#     board.article_delete()
#   elif (s.startswith("article edit")):
#     board.article_edit()
#   elif (s.startswith("article detail")):
#     board.article_detail()
#   else :
#     print("사용할수 없는 명령어 입니다. 명령어 확인은 help")
# Out:
# 사용자 입력lth
# 환영합니다.lth
# == CLI 게시판 실행 ==
# 명령어 : article write
# 제목 : hi
# 내용 : hi
# 1번 글이 생성되었습니다.
# 명령어 : article list
# ...
# 번호  /   제목   /   내용
# 1    /    hi    /    hi
# ...
# 명령어 : article detail 1
# 1번 게시글 입니다.
# 작성 시간 : 2026-09-01 11:27:56
# 수정 시간 : 2026-09-01 11:27:56
# 제목 : hi
# 내용 : hi
# 명령어 : article edit 1
# 1번 게시글 수정내용을 입력해주세요.
# 제목 : hi2
# 내용 : hi2
# 명령어 : article detail 1
# 1번 게시글 입니다.
# 작성 시간 : 2026-09-01 11:27:56
# 수정 시간 : 2026-09-01 11:28:21
# 제목 : hi2
# 내용 : hi2
# 명령어 : article detail 2
# 2번 게시글이 존재하지 않습니다.
# 명령어 : exit
# == CLI 게시판 종료 ==

# %%
# import datetime
# #기본적인 내용 만들기
# i = 1 #몇번째 숫자인지 출력
# articles = []
# article_id =1
# profiles = []
# profile_id=1
# o = 0
# print("== CLI 게시판 실행 ==")
# while(1):
#   #회원가입을 위한 부분 추가해야함.
#   if(o == 0):
#     print("게시판 이용을 위한 방법")
#     print("1. 로그인")
#     print("2. 회원가입")
#     start = int(input("숫자 입력 : 1,2"))
#     if(start == 1):
#       rid = str(input("아이디를 입력 :"))
#       rpwd = str(input("비밀번호를 입력 : "))
#       for i in profiles:
#         if(i["id"] == rid):
#           if(i["password"] == rpwd):
#             print("로그인 완료")
#             guest = i["name"]
#             o = 1
#       if(o == 0):
#         print("다시 로그인 해주세요.")
#         continue

#       #id랑 가지고 있는 정보값 비교
#     elif(start == 2):
#       kst_time = datetime.datetime.now(datetime.UTC) + datetime.timedelta(hours=9)
#       time = kst_time.strftime('%Y-%m-%d %H:%M:%S')#
#       print("회원가입 진행:")
#       name = input("이름 : ")
#       id = input("아이디: ")
#       pwd = input("비밀번호 : ")
#       profile = {
#               "name": name,
#               "id": id,
#               "password": pwd,
#               "registertime" : time
#           }
#       profiles.append(profile)
#       print("회원가입이 완료되었습니다.")
#       profile_id+=1
#       continue
#   print("{}님 환영합니다.".format(guest))
#   s = input("게시판 명령어 : ")
#   if((s) == "articlewrite"): # 글작성 부분
#     title = input("제목 : ")
#     main = input("내용 : ")
#     article = {
#             "id": article_id,
#             "title": title,
#             "main": main,
#             "writer": guest
#         }
#     articles.append(article)
#     print("{}번 글이 생성되었습니다.".format(article_id))
#     article_id+=1

#   elif((s) == "help"): #명령어 도움말
#     print("article write == 게시판 생성")
#     print("exit == 게시판 종료")
#     print("article list == 게시판 확인")
#     print("article delete == 게시판 제거")
#     print("article detail == 게시물 세부사항")

#   elif((s) == "exit"):# 프로그램 종료 명령어
#     break

#   elif (s.startswith("article list")): #게시글 목록 보기
#     num = s.split(" ")
#     target_id = int(num[2])
#     if not articles:
#         print("등록된 게시글이 없습니다.")
#         continue
#     print("="*30)
#     print("{}  /   {}   /   {}  ".format("번호","제목","내용"))
#     for article in reversed(articles):
#        print("{}    /    {}    /    {}   ".format(article["id"], article["title"], article["main"]))
#     print("="*30)

#   elif (s.startswith("article delete")):
#     num = s.split(" ")
#     target_id = int(num[2])
#     if not articles:
#             print("삭제할 게시글이 없습니다.")
#             continue
#         # 입력받은 번호(id)와 일치하는 게시글 찾기
#     target_article = None
#     for article in articles:
#       if article["id"] == target_id:
#           target_article = article
#           break

#     if target_article:
#             articles.remove(target_article)
#             print("{}번 게시글이 삭제되었습니다.".format(target_id))
#     else:
#             print("{}번 게시글이 존재하지 않습니다.".format(target_id))
#   elif (s.startswith("article edit")): #게시글 수정
#     num = s.split(" ")
#     target_id = int(num[2])
#     target_article = None
#     if not articles:
#             print("삭제할 게시글이 없습니다.")
#             continue
#     for article in articles:
#       if article["id"] == target_id:
#           target_article = article
#           break
#     if target_article:
#             print("{}번 게시글 수정내용을 입력해주세요.".format(target_id))
#     else:
#             print("{}번 게시글이 존재하지 않습니다.".format(target_id))
#             continue
#     edit_title = input("제목 : ")
#     edit_main = input("내용 : ")
#     target_article["title"] = edit_title
#     target_article["main"] = edit_main
#   elif(s.startswith("article detail")):
#     target_id = int(s[2])
#     for article in articles:
#       if article["id"] == target_id:
#           target_article = article
#           break
#     if target_article:
#             print("{}번 게시글을 확인하겠습니다.".format(target_id))
#             print("제목 : {}".format(target_article["title"]))
#             print("내용 : {}".format(target_article["main"]))


#     else:
#             print("{}번 게시글이 존재하지 않습니다.".format(target_id))
#             continue

#   else:
#     print("입력된 명령어가 없습니다. 명령어 확인 help")


# print("== CLI 게시판 종료 ==")

# %%
# #강사님 코드
# from datetime import datetime
# fake = Faker('ko-KR')
# articles =[]


# class Articles :
#   def __init__(self,id,regDate,updateDate,title,body):
#     self.id = id
#     self.title = title
#     self.body = body
#     self.regeDate = regDate
#     self.updateDate = updateDate



# print("== CLI 게시판 실행 ==")
# last_article_id = 0
# for i in range(1,4):
#   rdate = fake.date()
#   title = fake.job()
#   body = fake.catch_phrase()
#   articles.append({
#       "id" : i,
#       "regDate" : rdate,
#       "updateDate" :rdate,
#       "title" : title,
#       "body" : body
#   })
#   last_article_id = i


# def is_empty():
#     if not articles:
#         print("게시글이 없어")
#         return True
#     return False

# def get_article_by_cmd(cmd):
#     cmdBits = cmd.split(" ")
#     if len(cmdBits) < 3:
#         print("명령어 똑바로 써라(길이 모자람)")
#         return None
#     if not cmdBits[2].isdigit():
#         print("명령어 똑바로 써라(번호 대신 str 있는듯?)")
#         return None
#     target_id = int(cmdBits[2])
#     for article in articles:
#         if article["id"] == target_id:
#             return article

#     print("{}번 글은 없던데?".format(target_id))
#     return None

# while True:
#   cmd = input("명령어 ) ").strip()

#   if cmd == "exit":
#     break

#   elif cmd == "article write":
#     last_article_id += 1
#     id = last_article_id
#     regDate = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     updateDate = regDate
#     title = input("제목 : ")
#     body = input("내용 : ")

#     article = {"id" : id,
#                "regDate" : regDate,
#                "updateDate" : updateDate,
#                "title" : title,
#                "body" : body}
#     articles.append(article)

#     print("{}번 글이 생성되었습니다".format(last_article_id))
#   elif cmd == "article list":
#       if is_empty():
#         continue
#       today = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#       print("=========================================")
#       print("   번호      /     제목       /     내용         /     날짜    ")
#       for a in reversed(articles):
#         if today.split(" ")[0] != a["regDate"].split(" ")[0]:
#           print("    {}      /     {}       /     {}         /     {}    ".format(a["id"],a["title"],a["body"],a["regDate"].split(" ")[0]))
#         if today.split(" ")[0] == a["regDate"].split(" ")[0]:
#           print("    {}      /     {}       /     {}         /     {}    ".format(a["id"],a["title"],a["body"],a["regDate"].split(" ")[1]))
#       print("=========================================")
#   elif cmd.startswith("article delete"):
#     article = get_article_by_cmd(cmd)
#     if article:
#       articles.remove(article)
#       print("{}번 글 삭제됨".format(cmdBits[2]))


#     # for ~ else 도 있음
#   elif cmd.startswith("article edit"):
#     article = get_article_by_cmd(cmd)
#     if article:
#       # 기존 제목 내용 보여주기
#       print("기존 제목 : {}".format(article["title"]))
#       print("기존 내용 : {}".format(article["body"]))
#       # 새로 제목 내용 입력받아서 기존 내용 업데이트
#       article["title"] = input("새 제목 : ")
#       article["body"] = input("새 내용 : ")
#       article["updateDate"] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#       print("{}번 글 수정됨".format(article["id"]))
#       found = True

#   elif cmd.startswith("article detail"):
#     article = get_article_by_cmd(cmd)

#     if article:
#       #자세히 보여주기
#       print("==상세보기==")
#       print("번호 : {}".format(article["id"]))
#       print("작성 날짜 : {}".format(article["regDate"]))
#       print("수정 날짜 : {}".format(article["updateDate"]))
#       print("제목 : {}".format(article["title"]))
#       print("내용 : {}".format(article["body"]))
#       found = True
#   else:
#     print("지원하지 않는 명령어입니다.")

# print("== CLI 게시판 종료 ==")

# %%
from datetime import datetime
# 1. 가장 최신 상태
profiles = []
profile_id=3
o = 0
#==== 로그인 관련 부분 ====
profiles(1,"A","A","A")
profiles(2,"B","B","B")

print("== CLI 게시판 실행 ==")
while(1):
  #회원가입을 위한 부분 추가해야함.
  if(o == 0):
    print("게시판 이용을 위한 방법")
    print("1. 로그인")
    print("2. 회원가입")
    start = int(input("숫자 입력 : 1,2"))
    if(start == 1):
      rid = str(input("아이디를 입력 :"))
      rpwd = str(input("비밀번호를 입력 : "))
      for i in profiles:
        if(i["id"] == rid):
          if(i["password"] == rpwd):
            print("로그인 완료")
            guest = i["name"]
            o = 1
            break;
      if(o == 0):
        print("다시 로그인 해주세요.")
        continue

      #id랑 가지고 있는 정보값 비교
    elif(start == 2):
      while 1:
        print("회원가입 진행:")
        name = input("이름 : ")
        id = input("아이디: ")
        for i in profile:
          if(i["id"] == id):
            print("아이디를 다시 입력해주세요.")

        while(1):
          pwd = input("비밀번호 : ")
          tpwd = input("비밀번호 체크 : ")
          if(pwd != tpwd):
            print("비밀번호 다시 확인")
          else:
            break
        profile = {
                "name": name,
                "id": id,
                "password": pwd,
            }
        profiles.append(profile)
        print("회원가입이 완료되었습니다.")
        profile_id+=1
        break
  else:
    break




# ===== 공통 함수 (중복 제거) =====

def now():
    # 현재 시각을 "YYYY-MM-DD HH:MM:SS" 문자열로
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def parse_id(cmd):
    # "article delete 3" -> 3 을 뽑아준다. 잘못된 명령이면 None
    cmdBits = cmd.split(" ")
    if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        return None
    if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        return None
    return int(cmdBits[2])

def find_article(articles, article_id):
    # id가 맞는 글을 돌려준다. 없으면 None (found 플래그가 필요 없어짐)
    for article in articles:
        if article.id == article_id:
            return article
    return None

def format_date(regDate):
    # 오늘 쓴 글이면 시:분:초, 이전 글이면 연-월-일 로 보여준다
    today = now().split(" ")[0]        # "2026-09-01"
    datePart = regDate.split(" ")[0]   # 글의 날짜
    timePart = regDate.split(" ")[1]   # 글의 시각
    if datePart == today:
        return timePart
    else:
        return datePart

def makeTestData():
  return [
      Articles(1, "2025-12-12 12:12:12", "2025-12-12 12:12:12", "제목1", "내용1"),
      Articles(2, now(), now(), "제목2", "내용2"),
      Articles(3, now(), now(), "제목3", "내용3")
  ]

# ===== 메인 =====
class Articles :
  def __init__(self,id,regDate,updateDate,title,body):
    self.id = id
    self.title = title
    self.body = body
    self.regDate = regDate
    self.updateDate = updateDate


print("== CLI 게시판 실행 ==")

last_article_id = 3
articles = makeTestData()

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
        break

    elif cmd == "article write":
        last_article_id += 1
        title = input("제목 : ")
        body = input("내용 : ")
        article = Articles(last_article_id,now(),now(),title,body)
        articles.append(article)
        print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
        if not articles:
            print("게시글이 없습니다")
        else:
            print("=========================================")
            print("   번호      /     제목       /     내용   /     작성일   ")
            for a in reversed(articles):
                print("   {}      /     {}       /     {}          /     {}   ".format(a.id, a.title, a.body, format_date(a.regDate)))
            print("=========================================")

    elif cmd.startswith("article delete"):
        deletedId = parse_id(cmd)
        if deletedId is None:
            continue

        article = find_article(articles, deletedId)
        if article is None:
            print("{}번 글은 없습니다".format(deletedId))
            continue

        articles.remove(article)
        print("{}번 글이 삭제되었습니다".format(deletedId))

    elif cmd.startswith("article edit"):
        editedId = parse_id(cmd)
        if editedId is None:
            continue

        article = find_article(articles, editedId)
        # 1. 함수가 자기 재료를 눈에 보이게 받는게 더 안전하고 명확함
        # 2. 클래스 사용시 편함(전역에 의존하면 안됨)
        # -> '이 함수가 뭘 필요로 하는지 인자로 다 받는다' 의 습관
        # -> "함수는 독립적이어야 한다"
        if article is None:
            print("{}번 글은 없습니다".format(editedId))
            continue

        print("기존 제목 : {}".format(article.title))
        print("기존 내용 : {}".format(article.body))
        article.title = input("새 제목 : ")
        article.body = input("새 내용 : ")
        article.updateDate = now()
        print("{}번 글이 수정되었습니다".format(editedId))

    elif cmd.startswith("article detail"):
        detailId = parse_id(cmd)
        if detailId is None:
            continue

        article = find_article(articles, detailId)
        if article is None:
            print("{}번 글은 없습니다".format(detailId))
            continue

        print("번호 : {}".format(article.id))
        print("작성 날짜 : {}".format(article.regDate))
        print("수정 날짜 : {}".format(article.updateDate))
        print("제목 : {}".format(article.title))
        print("내용 : {}".format(article.body))

    else:
        print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 게시판 이용을 위한 방법
# 1. 로그인
# 2. 회원가입
# 숫자 입력 : 1,22
# 회원가입 진행:
# 이름 : l
# 아이디: t
# 아이디를 다시 입력해주세요.
# 회원가입 진행:
