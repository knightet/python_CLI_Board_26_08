# %% [markdown]
# <a href="https://colab.research.google.com/github/knightet/python_CLI_Board_26_08/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_CLI_Board.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user = input("사용자 입력")
class cli:
  def __init__(self): # 게시글 실행
    print("환영합니다.{}".format(user))
    print("== CLI 게시판 실행 ==")
  def articlewrite(self): # 게시글 생성
    title = input("제목 : ")
    main = input("내용 : ")
    print("{}번 글이 생성되었습니다.".format(i))
    i+=1
  def exit(self): # 게시판 나가는것
    print("게시판 종료")
  def check(self):# 게시판 명령어 확인
    print("명령어 확인")
    print("article write == 게시판 생성")
    print("exit == 게시판 종료")


board = cli()
while(1):
  s = input("명령어 : ")
  if (s == "articlewrite"):
    board.articlewrite()
  elif (s == "exit"):
    board.exit()
    print("== CLI 게시판 종료 ==")
    break
  elif (s == "check"):
    board.check()
  else :
    print("사용할수 없는 명령어 입니다. 명령어 확인은 check")
# Out:
# 사용자 입력lth
# 환영합니다.lth
# == CLI 게시판 실행 ==
# 명령어 : hi
# 사용할수 없는 명령어 입니다. 명령어 확인은 check
# 명령어 : hi
# 사용할수 없는 명령어 입니다. 명령어 확인은 check
# 명령어 : check
# 명령어 확인
# article write == 게시판 생성
# exit == 게시판 종료
# 명령어 : articlewrite
# 제목 : hi
# 내용 : hi
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_1028/2731625447.py in <cell line: 0>()
#      22   s = input("명령어 : ")
#      23   if (s == "articlewrite"):
# ---> 24     board.articlewrite()
#      25   elif (s == "exit"):
#      26     board.exit()
#
# /tmp/ipykernel_1028/2731625447.py in articlewrite(self)
#       8     title = input("제목 : ")
#       9     main = input("내용 : ")
# ---> 10     print("{}번 글이 생성되었습니다.".format(i))
#      11     i+=1
#      12   def exit(self): #게시판 나가는것
#
# UnboundLocalError: cannot access local variable 'i' where it is not associated with a value

# %%
i = 1 #몇번째 숫자인지 출력

print("== CLI 게시판 실행 ==")
while(1):
  s = input("명령어 : ")
  if(s == "article write"):
    title = input("제목 :")
    main = input("내용 : ")
    print("{}번 글이 생성되었습니다.".format(i))
    i+=1
  elif(s == "check"):
    print("article write == 게시판 생성")
    print("exit == 게시판 종료")
  elif(s == "exit"):
    break
  else:
    print("사용할수 없는 명령어 입니다. 명령어 확인은 check")
print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 : hi
# 사용할수 없는 명령어 입니다. 명령어 확인은 check
# 명령어 : article write
# 제목 :hi
# 내용 : hi
# 1번 글이 생성되었습니다.
# 명령어 : hi
# 사용할수 없는 명령어 입니다. 명령어 확인은 check
# 명령어 : article write
# 제목 :hi
# 내용 : hi
# 2번 글이 생성되었습니다.
# 명령어 : exit
# == CLI 게시판 종료 ==
